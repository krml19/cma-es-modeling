# %%
from scripts.benchmarks import Cube, Ball, Simplex
import matplotlib.pyplot as plt
from scripts.drawer import draw
# %matplotlib inline

# %%
cube = Cube.Cube(i=2, d=2.7)
cube_df = cube.generate_df()
draw.draw2d(df=cube_df, selected=[0, 1])

# %%
cube = Cube.Cube(i=3, d=2.7)
cube_df = cube.generate_df()
draw.draw3d(df=cube_df, selected=[0, 1, 2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/projections/__init__.py in get_projection_class(projection)
#      62     try:
# ---> 63         return projection_registry.get_projection_class(projection)
#      64     except KeyError:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/projections/__init__.py in get_projection_class(self, name)
#      28         """
# ---> 29         return self._all_projection_types[name]
#      30
#
# KeyError: '3d'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-02b2065699d4> in <module>()
#       1 cube = Cube.Cube(i=3, d=2.7)
#       2 cube_df = cube.generate_df()
# ----> 3 draw.draw3d(df=cube_df, selected=[0, 1, 2])
#
# ~/GitHub/cma-es-modeling/scripts/drawer/draw.py in draw3d(df, selected)
#      12 def draw3d(df, selected=[0, 1, 2]):
#      13     fig = plt.figure()
# ---> 14     ax = fig.add_subplot(111, projection='3d')
#      15
#      16     for x, y, z, v in zip(df[df.columns[selected[0]]].values, df[df.columns[selected[1]]].values, df[df.columns[selected[2]]].values, df['valid'].values):
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1050         else:
#    1051             projection_class, kwargs, key = process_projection_requirements(
# -> 1052                 self, *args, **kwargs)
#    1053
#    1054             # try to find the axes with this key in the stack
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/projections/__init__.py in process_projection_requirements(figure, *args, **kwargs)
#      89
#      90     if isinstance(projection, six.string_types) or projection is None:
# ---> 91         projection_class = get_projection_class(projection)
#      92     elif hasattr(projection, '_as_mpl_axes'):
#      93         projection_class, extra_kwargs = projection._as_mpl_axes()
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/projections/__init__.py in get_projection_class(projection)
#      63         return projection_registry.get_projection_class(projection)
#      64     except KeyError:
# ---> 65         raise ValueError("Unknown projection '%s'" % projection)
#      66
#      67
#
# ValueError: Unknown projection '3d'

# %%
ball = Ball.Ball(i=2, d=2.7)
ball_df = ball.generate_df()

# %%
simplex = Simplex.Simplex(i=2, d=2.7)
simplex_df = simplex.generate_df()
